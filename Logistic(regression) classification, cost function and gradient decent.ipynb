# %% [markdown]
# ![logistic%20regression%20cost.jpg](attachment:logistic%20regression%20cost.jpg)

# %% [markdown]
# 위에 그림처럼, linear regression때는 cost를 구할때 직선이(H(x)) 제곱되는 계산이 이루어 진다. 그래서 이차함수 형태의 cost 모양이 나왔고, Logistic regression에서는 기존에 H(x)가 곡선이기 때문에, 제곱을 하였을때(="cost 함수를 계산할때") 저렇게 곡선의 연속(??)이 반복되는 형태가 나오게 된다. 이때 문제가 뭐냐면 local minimum에서 해를 찾아서, gradient descent로는 실제 최저점에 도달하지 못하게 되는 것이다.

# %% [markdown]
# ![%EC%A0%9C%EB%AA%A9%20%EC%97%86%EC%9D%8C.jpg](attachment:%EC%A0%9C%EB%AA%A9%20%EC%97%86%EC%9D%8C.jpg)

# %% [markdown]
# 그래서 cost함수를 저렇게 만드는데, 설명을 하자면, 절케 -log함수가 있는데, h(x)의 범위가 0에서 1사이므로, 저렇게 분홍색 부분만 범위에 해당한다, 그래서 위 그림 왼쪽 하단의 그래프가 나온다

# %% [markdown]
# ![%EC%A0%9C%EB%AA%A9%20%EC%97%86%EC%9D%8C.jpg](attachment:%EC%A0%9C%EB%AA%A9%20%EC%97%86%EC%9D%8C.jpg)

# %% [markdown]
# ![%EC%A0%9C%EB%AA%A9%20%EC%97%86%EC%9D%8C.jpg](attachment:%EC%A0%9C%EB%AA%A9%20%EC%97%86%EC%9D%8C.jpg)

# %% [markdown]
# 위도 같은 원리이다 ㅋㅋㅋ

# %% [markdown]
# ![%EC%A0%9C%EB%AA%A9%20%EC%97%86%EC%9D%8C.jpg](attachment:%EC%A0%9C%EB%AA%A9%20%EC%97%86%EC%9D%8C.jpg)

# %% [markdown]
# 그래서 cost함수를 다시 살펴보면, y가 1일때, H(x)도 1이라면, 정확하게 예측한 것이므로 cost가 0이다. 그리고 H(x)가 0이면, 부정확한 것이므로 cost가 무한대이다.

# %% [markdown]
# ![%EC%A0%9C%EB%AA%A9%20%EC%97%86%EC%9D%8C.jpg](attachment:%EC%A0%9C%EB%AA%A9%20%EC%97%86%EC%9D%8C.jpg)

# %% [markdown]
# ![%EC%A0%9C%EB%AA%A9%20%EC%97%86%EC%9D%8C.jpg](attachment:%EC%A0%9C%EB%AA%A9%20%EC%97%86%EC%9D%8C.jpg)

# %% [markdown]
# 위에 그림에서, 완벽하게 다 알 필요는 없는데, 일단 저 cost함수를 그려보면 기존의 linear regression에서 처럼 이차함수 형태로 매끄럽게 생겼고, 그 함수에서 gradient descent로 minimum을 찾아서 내려가는 코드이다.
