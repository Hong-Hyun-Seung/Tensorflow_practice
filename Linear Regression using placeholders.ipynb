# %% [markdown]
# 8월 24일 캡쳐 이미지 꼭 보기!!!!

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From C:\Users\EK Hong\.conda\envs\tensorflow\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')
X = tf.placeholder(tf.float32, shape=[None])
Y = tf.placeholder(tf.float32, shape= [None])
#위에서 처럼 placeholder는 shape을 None으로 줄수 있고, 이것의 의미는 
#일차원 배열인데, 배열 안에 원소의 갯수는 상관 없다는 것이다

# %%
#Our hypothesis XW + b
hypothesis = X * W + b
#cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))
#Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)
#optimizer를 정의하고,
#optimizer에서 minimize라는 함수를 호출해서 cost를 minimize한다

# %%
#Launch the graph in a session
sess = tf.Session()
#Initializes global variables in the graph
sess.run(tf.global_variables_initializer())

# %%
#Fit the line with new training data
for step in range(2001):
    cost_val,W_val,b_val,_ = sess.run([cost, W,b,train], #train은 저장할 필요가 없자나
        feed_dict={X:[1,2,3,4,5],
                  Y:[2.1,3.1,4.1,5.1,6.1]})
    if step%20 == 0:
        print(step, cost_val, W_val, b_val)
# Out:
# 0 29.608707 [0.26663345] [-0.7438476]
# 20 0.37220198 [1.3892102] [-0.32545987]
# 40 0.32452688 [1.368574] [-0.23076102]
# 60 0.28341165 [1.3444579] [-0.14360239]
# 80 0.24750564 [1.321899] [-0.06215794]
# 100 0.2161484 [1.3008176] [0.0139527]
# 120 0.18876413 [1.2811168] [0.08507885]
# 140 0.16484906 [1.2627064] [0.15154682]
# 160 0.14396384 [1.2455014] [0.21366179]
# 180 0.12572473 [1.2294234] [0.27170882]
# 200 0.109796405 [1.2143981] [0.32595426]
# 220 0.09588602 [1.2003571] [0.37664706]
# 240 0.08373797 [1.1872357] [0.42401996]
# 260 0.07312899 [1.1749735] [0.46829042]
# 280 0.06386406 [1.1635141] [0.5096617]
# 300 0.05577298 [1.1528054] [0.54832345]
# 320 0.04870698 [1.1427982] [0.5844531]
# 340 0.042536132 [1.1334462] [0.6182167]
# 360 0.037147112 [1.1247067] [0.64976907]
# 380 0.03244085 [1.1165396] [0.6792551]
# 400 0.028330836 [1.1089073] [0.70681006]
# 420 0.024741534 [1.1017748] [0.7325602]
# 440 0.021606974 [1.0951096] [0.7566241]
# 460 0.018869556 [1.0888809] [0.779112]
# 480 0.016478915 [1.0830599] [0.80012715]
# 500 0.014391164 [1.0776203] [0.8197661]
# 520 0.012567898 [1.072537] [0.8381188]
# 540 0.010975619 [1.0677863] [0.8552697]
# 560 0.009585101 [1.063347] [0.87129736]
# 580 0.008370737 [1.0591983] [0.8862753]
# 600 0.0073102294 [1.0553213] [0.90027237]
# 620 0.0063840724 [1.0516984] [0.91335267]
# 640 0.005575254 [1.0483125] [0.92557627]
# 660 0.004868922 [1.0451485] [0.93699944]
# 680 0.004252072 [1.0421917] [0.9476745]
# 700 0.0037133545 [1.0394285] [0.9576504]
# 720 0.0032428843 [1.0368463] [0.9669731]
# 740 0.002832043 [1.0344331] [0.9756852]
# 760 0.0024732412 [1.032178] [0.98382676]
# 780 0.002159908 [1.0300707] [0.991435]
# 800 0.0018862605 [1.0281013] [0.998545]
# 820 0.0016472765 [1.026261] [1.0051894]
# 840 0.0014385782 [1.0245413] [1.0113986]
# 860 0.0012563358 [1.022934] [1.0172008]
# 880 0.0010971712 [1.0214322] [1.0226232]
# 900 0.00095816964 [1.0200284] [1.0276908]
# 920 0.0008367702 [1.0187168] [1.0324264]
# 940 0.00073076756 [1.017491] [1.0368518]
# 960 0.00063817285 [1.0163455] [1.0409875]
# 980 0.0005573307 [1.015275] [1.0448521]
# 1000 0.00048671826 [1.0142747] [1.0484641]
# 1020 0.00042504515 [1.0133398] [1.0518394]
# 1040 0.0003712002 [1.0124661] [1.0549934]
# 1060 0.00032417226 [1.0116496] [1.0579408]
# 1080 0.00028310317 [1.0108868] [1.0606953]
# 1100 0.00024723582 [1.0101738] [1.0632693]
# 1120 0.00021591212 [1.0095074] [1.0656749]
# 1140 0.0001885591 [1.0088848] [1.0679228]
# 1160 0.00016466793 [1.008303] [1.0700237]
# 1180 0.00014380597 [1.0077591] [1.0719868]
# 1200 0.0001255845 [1.007251] [1.0738215]
# 1220 0.00010967563 [1.0067761] [1.075536]
# 1240 9.577904e-05 [1.0063324] [1.0771382]
# 1260 8.36466e-05 [1.0059177] [1.0786352]
# 1280 7.304653e-05 [1.0055301] [1.0800347]
# 1300 6.379023e-05 [1.0051678] [1.0813423]
# 1320 5.570909e-05 [1.0048294] [1.0825644]
# 1340 4.8652662e-05 [1.0045131] [1.0837061]
# 1360 4.2488024e-05 [1.0042176] [1.0847732]
# 1380 3.710659e-05 [1.0039413] [1.0857702]
# 1400 3.2403248e-05 [1.0036832] [1.0867022]
# 1420 2.8298586e-05 [1.003442] [1.0875732]
# 1440 2.4712348e-05 [1.0032166] [1.0883871]
# 1460 2.158221e-05 [1.003006] [1.0891474]
# 1480 1.884707e-05 [1.002809] [1.0898585]
# 1500 1.6459559e-05 [1.002625] [1.0905229]
# 1520 1.4373424e-05 [1.0024531] [1.0911435]
# 1540 1.2553093e-05 [1.0022925] [1.0917234]
# 1560 1.0962169e-05 [1.0021423] [1.0922655]
# 1580 9.573769e-06 [1.0020021] [1.092772]
# 1600 8.360295e-06 [1.0018709] [1.0932455]
# 1620 7.300993e-06 [1.0017483] [1.0936879]
# 1640 6.376146e-06 [1.0016339] [1.0941012]
# 1660 5.568895e-06 [1.001527] [1.0944874]
# 1680 4.8624543e-06 [1.0014268] [1.0948486]
# 1700 4.246934e-06 [1.0013335] [1.095186]
# 1720 3.7086363e-06 [1.0012461] [1.0955012]
# 1740 3.2387475e-06 [1.0011646] [1.0957958]
# 1760 2.8284849e-06 [1.0010884] [1.096071]
# 1780 2.4704484e-06 [1.0010171] [1.0963283]
# 1800 2.1574124e-06 [1.0009505] [1.0965687]
# 1820 1.8841331e-06 [1.0008882] [1.0967933]
# 1840 1.6455999e-06 [1.00083] [1.0970032]
# 1860 1.4373949e-06 [1.0007758] [1.0971993]
# 1880 1.2555638e-06 [1.0007249] [1.0973825]
# 1900 1.0966477e-06 [1.0006776] [1.0975538]
# 1920 9.576426e-07 [1.0006332] [1.097714]
# 1940 8.363333e-07 [1.0005918] [1.0978637]
# 1960 7.3039297e-07 [1.000553] [1.0980035]
# 1980 6.38135e-07 [1.0005168] [1.098134]
# 2000 5.572082e-07 [1.0004829] [1.0982562]

# %%
print(sess.run(hypothesis, feed_dict={X:[5]}))
print(sess.run(hypothesis, feed_dict={X:[2.5]}))
print(sess.run(hypothesis, feed_dict={X:[1.5, 3.5]}))
# Out:
# [6.100671]
# [3.5994635]
# [2.5989804 4.5999465]
