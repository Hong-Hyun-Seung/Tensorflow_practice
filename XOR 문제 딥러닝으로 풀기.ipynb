# %% [markdown]
# 기존의 one lever neural network에서는 xor과 같은 문제는 못 푼다고 했는데, two level neural network에서 xor문제가 해결 가능해진다

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#코드로 위에 두 줄을 나타내면
#K = tf.sigmoid(tf.matmul(X,W1) + B1)
#hypothesis = tf.sigmoid(tf.matmul(K, W2) + B2)
